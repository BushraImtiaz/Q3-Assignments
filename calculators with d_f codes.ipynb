# %%
a=input('please enter first value : ')
b=input('please enter second value : ')
c=int(a)+int(b)
d=int(a)-int(b)
e=int(a)*int(b)
f=int(a)/int(b)
print(str(a) + " + " + str(b) + " = " + str(c))
print(str(a) + " - " + str(b) + " = " + str(d))
print(str(a) + " x " + str(b) + " = " + str(e))
print(str(a) + " / " + str(b) + " = " + str(f))
# Out:
# please enter first value : 12
# please enter second value : 33
# 12 + 33 = 45
# 12 - 33 = -21
# 12 x 33 = 396
# 12 / 33 = 0.36363636363636365

# %%
a = int(input("Enter the 1st Number: "))
b = int(input("Enter the 2nd Number: "))

c =int(a+b)
print("Add :",c)
d =int(a-b)
print("sub :",d)
e =int(a*b)
print("mutiply is :",e)
f =int(a/b)
print("divide :",f)
# Out:
# Enter the 1st Number: 12
# Enter the 2nd Number: 33
# Add : 45
# sub : -21
# mutiply is : 396
# divide : 0

# %%
num1 = input ("Enter Number 1: ")
num2 = input("Enter Number 2: ")
print(int(num1) + int(num2))
print(int(num1) - int(num2))
print(int(num1) / int(num2))
print(int(num1) * int(num2))
# Out:
# Enter Number 1: 33
# Enter Number 2: 99
# 132
# -66
# 0.3333333333333333
# 3267

# %%
#Assignment 1
#Simple Calculator
#BUSHRA IMTIAZ
operator=input('''please select math operator to perform:
+ for addition
- for subtraction
/ for division
* for multiplication''')

fNo=int(input("please enter first no:   "))
sNo=int(input("please enter second no:   "))

if operator=='+':
    print("Result is :",fNo+sNo)

elif operator=='-':
    print("Result is :",fNo-sNo)

elif operator=='/':
    print("Result is :",fNo/sNo)

elif operator =="*":
    print("Result is :",fNo*sNo)
# Out:
# please select math operator to perform:
# + for addition
# - for subtraction
# / for division
# * for multiplication44
# please enter first no:   55
# please enter second no:   66

# %%
print('"First we do for Float Division"')
a=input("Enter first number: ")
b=input("Enter second number: ")
c=int(a)/int(b)
print(c)

### Now for Integer division
print('"Now we do for Integer Division"')
a=input("Enter first number: ")
b=input("Enter second number: ")
c=int(a)//int(b)
print(c)

### Now Multiplication
print("Now we do for Multiplication")
a=input("Enter first number: ")
b=input("Enter second number: ")
c=int(a)*int(b)
print(c)

#### Now Addition
print('"Now we do for Addition"')
a=input("Enter first number:")
b=input("Enter second number:")
c=int(a)+int(b)
print(c)

### Now For Substraction

print('"Now we do for Substraction"')
a=input("Enter first number:")
b=input("Enter second number:")
c=int(a)-int(b)
print(c)
# Out:
# "First we do for Float Division"
# Enter first number: 66
# Enter second number: 44
# 1.5
# "Now we do for Integer Division"
# Enter first number: 7
# Enter second number: 67
# 0
# Now we do for Multiplication
# Enter first number: 7
# Enter second number: 4
# 28
# "Now we do for Addition"
# Enter first number:7
# Enter second number:8
# 15
# "Now we do for Substraction"
# Enter first number:8
# Enter second number:5
# 3

# %%
f_no = input("Please enter first Number")
s_no = input("Please enter Second Number")
c = int(f_no) / int(s_no)
print(c)
c = int(f_no) * int(s_no)
print(c)
c = int(f_no) + int(s_no)
print(c)
c = int(f_no) - int(s_no)
print(c)
# Out:
# Please enter first Number34
# Please enter Second Number33
# 1.0303030303030303
# 1122
# 67
# 1

# %%
# by using if else perform arithmetic operation
print("\t\t==============================================================================================================================\t")
print("\t\tDesign a simple calcultor to perform a basic operation\t")
print("\t\t==============================================================================================================================\t")
#take input of two numbers in float
operand1 =float(input("\t\tenter first number:"))
operand2 =float(input("\t\tenter second number:"))
# take operator as string
operator=input("\t\tenter a operator to perform calculation:")
#add two numbers, 
if operator=='+':
    result= operand1 + operand2
    print("\t\t==============================================================================================================================\t")
# here str() operation use in print to concatenate(join) string and int. two different types of data ca print with each other until the type will not be changed
    print("\t\t The sum of two number is:"+str(result))
    print("\t\t==============================================================================================================================\t")
#subtract two number
elif operator=='-':
    result= operand1 - operand2
    print("\t\t==============================================================================================================================\t")
    print("\t\t The subtraction of two number is:"+str(result))
    print("\t\t==============================================================================================================================\t")
#multiply two numbers
elif operator=='*':
    result= operand1 * operand2
    print("\t\t==============================================================================================================================\t")
    print("\t\t The multiplication of two number is:"+str(result))
    print("\t\t==============================================================================================================================\t")
#divide two numbers
elif operator=='/':
    result= operand1 / operand2
    print("\t\t==============================================================================================================================\t")
    print("\t\t The division of two number is:"+str(result))
    print("\t\t==============================================================================================================================\t")
# when input wrong operator gives output as invalid operation
else:
    print("\t\t==============================================================================================================================\t")
    print("\t\t input invalid operation")
    print("\t\t==============================================================================================================================\t")
# Out:
# ...
# 		Design a simple calcultor to perform a basic operation
# ...
# 		enter first number:56
# 		enter second number:77
# 		enter a operator to perform calculation:+
# ...
# 		 The sum of two number is:133.0
# ...

# %%
#This program will take two input of two numbers
#Author Rida Hamid

operand = int(input("Enter  your first digit: "))
operand2 = int(input("Enter  your second digit: "))
operation=input("Enter your operator 1:Addition 2:Subtraction 3:Multiplication 4:Division ")
if operation == '1':
    print('addition:  ' ,  operand + operand2)
elif operation == '2':
    print('subtraction: ' , operand - operand2)
elif operation =='3':
    print('multiplication: ', operand * operand2)
elif operation == '4':
    print('division:' , operand / operand2)
# Out:
# Enter  your first digit: 66
# Enter  your second digit: 9
# Enter your operator 1:Addition 2:Subtraction 3:Multiplication 4:Division 7

# %%
a=int(input('enter a number '))
b=int(input('enter second number '))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
#comment addition,subtraction,multiplication,float division(/),integer division(//),modulus operator remainder(%) (**-square)
# Out:
# enter a number 66
# enter second number 88
# 154
# -22
# 5808
# 0.75
# 0
# 66
# 13178510522716872655319238066254261900640428904597084991084305835847338167564624007457480583106103029669005706620759237604335830854305162036310315064928969424896
